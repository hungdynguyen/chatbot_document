# %%
import os
import time
import shutil

os.system("docker rm -f qdrant-container > /dev/null 2>&1")

print("\n🐳 Đang khởi động container Qdrant mới...")
os.system("""
docker run -d \
    --name qdrant-container \
    -p 6333:6333 \
    -p 6334:6334 \
    -v "$(pwd)/qdrant_storage:/qdrant/storage:z" \
    qdrant/qdrant:latest
""")
print("✅ Qdrant đã sẵn sàng. Chờ 2 giây để khởi động hoàn tất...")
time.sleep(2)
# Out:
# 🐳 Đang khởi động container Qdrant mới...
# 09940e4a57d471acc7b3489a5d7296f82a04f801f3104a6e1f86d1a6690658b6
# ✅ Qdrant đã sẵn sàng. Chờ 2 giây để khởi động hoàn tất...

# %%
# IMPORT PACKAGES
import os
import json
from pathlib import Path
from typing import List, Tuple, Dict
import time
import uuid
import numpy as np
import pandas as pd
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from sentence_transformers import CrossEncoder
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams, PointStruct
from langchain_openai import ChatOpenAI 
import torch
from config import (
    DEEPSEEK_API_KEY,
    QDRANT_HOST,
    QDRANT_PORT,
    COLLECTION_NAME,
    DELAY_BETWEEN_CALLS,
    EMBEDDING_MODEL_NAME,
    EMBEDDING_DEVICE,
    LIST_GOOGLE_API_KEYS,
    RERANKER_MODEL_NAME,
    RERANKER_DEVICE
)

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings(
    "ignore", 
    message="flash_attn is not installed. Using PyTorch native attention implementation."
)

# %% [markdown]
# # Generate Evaluation Dataset (Full Flow Advanced RAG + Get Context)
#
# - ChatGPT OSS: Response
# - Gemini 2.5 Pro: Parsing

# %%
# --- KHỞI TẠO CÁC MODEL ---
print("🧠 Đang khởi tạo các model")
from langchain_together import ChatTogether

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"✅ Sử dụng thiết bị: {device}")
# Embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL_NAME,
    model_kwargs={"device": device, "trust_remote_code": True}
)

# LLM
try:
    deepseek_llm_client = ChatOpenAI(
        model="deepseek-chat",
        api_key=DEEPSEEK_API_KEY,
        base_url="https://api.deepseek.com/v1",
        temperature=0.3,    
    )
    print("✅ DeepSeek client đã sẵn sàng.")
except Exception as e:
    print(f"❌ Lỗi khi khởi tạo DeepSeek client: {e}")
    deepseek_llm_client = None
# ChatGPT OSS
try: 
    chatgpt_oss_client = ChatTogether(
        together_api_key="",
        model="openai/gpt-oss-120b",
    )
    print("✅ ChatGPT OSS client đã sẵn sàng.")
except Exception as e:
    print(f"❌ Lỗi khi khởi tạo ChatGPT OSS client: {e}")
    chatgpt_oss_client = None
# Reranker model
reranker_model = CrossEncoder(model_name_or_path= RERANKER_MODEL_NAME,
                              device=RERANKER_DEVICE,
                              trust_remote_code=True)
print("✅ Reranker model đã sẵn sàng.")
qdrant_client = QdrantClient(host=QDRANT_HOST, port=QDRANT_PORT)
print("✅ Các model đã sẵn sàng.")

# Clear previous collection of Qdrant if exists
def clear_qdrant_collection():
    """Xóa collection để đảm bảo dữ liệu mới mỗi lần chạy."""
    try:
        qdrant_client.delete_collection(collection_name=COLLECTION_NAME)
        print(f"✅ Đã xóa collection '{COLLECTION_NAME}' (nếu tồn tại).")
    except Exception:
        pass 
# Setup Qdrant collection 
def setup_qdrant_collection(embedding_dim: int):
    """Tạo hoặc tái tạo collection trong Qdrant."""
    try:
        qdrant_client.recreate_collection(
            collection_name=COLLECTION_NAME,
            vectors_config=VectorParams(size=embedding_dim, distance=Distance.COSINE)
        )
        print(f"✅ Đã tạo/tái tạo collection '{COLLECTION_NAME}' trong Qdrant.")
        return True
    except Exception as e:
        print(f"❌ Lỗi khi setup Qdrant collection: {e}")
        return False

# Store chunks in Qdrant
def store_child_chunks_in_qdrant(child_chunks: List[Document], child_embeddings: np.ndarray):
    """Lưu child chunks và embeddings vào Qdrant."""
    points = []
    for chunk, emb in zip(child_chunks, child_embeddings):
        payload = {
            "content": chunk.page_content,
            "parent_id": chunk.metadata.get("parent_id"),
            "parent_content": chunk.metadata.get("parent_content"),
            "source": chunk.metadata.get("source", "unknown")
        }
        points.append(PointStruct(id=str(uuid.uuid4()), vector=emb.tolist(), payload=payload))
    qdrant_client.upsert(collection_name=COLLECTION_NAME, points=points, wait=True)
    print(f"✅ Đã lưu {len(points)} child chunks vào Qdrant.")

# Parent - Child chunking strategy and Embedding in Qdrant
def setup_small_to_big_data_with_qdrant(markdown_content: str):
    """Chuẩn bị dữ liệu cho chiến lược Small-to-Big và lưu vào Qdrant."""
    print("--- Bước 1: Chuẩn bị dữ liệu Small-to-Big với Qdrant ---")
    parent_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
    child_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=50)
    parent_chunks = parent_splitter.create_documents([markdown_content])
    print(f"✅ Đã tạo {len(parent_chunks)} parent chunks (đoạn văn lớn).")

    all_child_chunks = []
    for i, p_chunk in enumerate(parent_chunks):
        child_texts = child_splitter.split_text(p_chunk.page_content)
        for text in child_texts:
            all_child_chunks.append(Document(page_content=text, metadata={"parent_id": i, "parent_content": p_chunk.page_content}))
    print(f"✅ Đã tạo {len(all_child_chunks)} child chunks (câu nhỏ) từ các parent.")
            
    sample_embedding = embedding_model.embed_query("test")
    if not setup_qdrant_collection(len(sample_embedding)): 
        return None, False
    
    print("🧠 Đang embedding các child chunks...")
    child_contents = [c.page_content for c in all_child_chunks]
    child_embeddings = np.array(embedding_model.embed_documents(child_contents))
    print("✅ Embedding child chunks hoàn tất!")
    
    store_child_chunks_in_qdrant(all_child_chunks, child_embeddings)
    return parent_chunks, True

def retrieve_context_list(query: str, top_k_final: int = 3, retrieve_k_children: int = 15) -> List[str]:
    """
    Pipeline RAG: Search child chunks --> Mapping parents --> Reranking parents --> Return top-k parents.
    """
    query_embedding = embedding_model.embed_query(query)
    search_results = qdrant_client.search(collection_name=COLLECTION_NAME, query_vector=query_embedding, limit=retrieve_k_children, with_payload=True)
    
    candidate_parents = {hit.payload["parent_content"] for hit in search_results if hit.payload and "parent_content" in hit.payload}
    
    if not candidate_parents: return [] 
    
    parent_contents = list(candidate_parents)
    pairs = [(query, content) for content in parent_contents]
    scores = reranker_model.predict(pairs)
    reranked_results = sorted(zip(scores, parent_contents), key=lambda x: x[0], reverse=True)
    
    final_docs = [content for _, content in reranked_results[:top_k_final]]
    return final_docs

def format_chat_history_for_prompt(history: List[Dict[str, str]]) -> str:
    """Định dạng lịch sử chat thành một chuỗi đẹp mắt cho prompt."""
    if not history:
        return "Đây là câu hỏi đầu tiên trong cuộc trò chuyện."
    
    formatted_string = ""
    for turn in history:
        # Giả định mỗi turn là một dict có 'question' và 'answer'
        formatted_string += f"Người dùng đã hỏi: {turn['question']}\nTrợ lý đã trả lời: {turn['answer']}\n\n"
    return formatted_string.strip()
 
def answer_with_context(query: str, context_list: List[str], chat_history: List[Dict[str, str]]) -> str: 
    """Sử dụng LLM để trả lời câu hỏi dựa trên context được cung cấp."""
    
    full_context_str = "\n\n---\n\n".join(context_list)
    formatted_history = format_chat_history_for_prompt(chat_history)

    prompt_template = f"""Bạn là một trợ lý AI chuyên nghiệp, chỉ trả lời dựa trên context được cung cấp.
    Trả lời câu hỏi một cách ngắn gọn và chính xác. Nếu không có thông tin trong context, hãy nói "Tôi không tìm thấy thông tin trong tài liệu."
    **Sử dụng LỊCH SỬ TRÒ CHUYỆN:** Đọc kỹ lịch sử để hiểu ngữ cảnh. Ví dụ, nếu câu hỏi hiện tại là "doanh thu công ty này là bao nhiêu?", bạn phải dựa vào lịch sử để biết "công ty này" là công ty nào và người dùng đang hỏi về thông tin gì (doanh thu, sản phẩm, v.v.).
    LỊCH SỬ TRÒ CHUYỆN (để tham khảo ngữ cảnh):
    {formatted_history}
    Context:
    ---
    {full_context_str}
    ---
    

    Câu hỏi: {query}

    Trả lời:
    """
    response = chatgpt_oss_client.invoke(prompt_template)
    return response.content

# --- CHẠY PIPELINE VÀ THU THẬP DỮ LIỆU ---

def main():
    """
    Hàm chính để thực thi toàn bộ pipeline RAG và đánh giá.
    """
    generated_data_for_eval = [] 
    markdown_file_path = Path("/root/chatbot1/chatbot_document/backend/output_parsing/gemini-2.5-raw-input.md")
    knowledge_base = []
    if not markdown_file_path.exists():
        print(f"❌ Lỗi: Không tìm thấy file {markdown_file_path}. Vui lòng chạy bước parsing trước.")
        return 

    with open(markdown_file_path, 'r', encoding='utf-8') as f:
        markdown_content = f.read()

    clear_qdrant_collection()
    parent_chunks, success = setup_small_to_big_data_with_qdrant(markdown_content)
    
    if not success:
        print("❌ Không thể setup dữ liệu với Qdrant. Dừng chương trình.")
        return 

    # Lấy câu hỏi từ file ragasdf_base.json
    with open(Path("/root/chatbot1/new_ragas/schemas/ragasdf_base.json"), 'r', encoding='utf-8') as f:
        queries_data = json.load(f)
    queries = [item['question'] for item in queries_data]

    print(f"\n\n=== 🚀 BẮT ĐẦU CHẠY RAG VÀ THU THẬP DỮ LIỆU TRÊN {len(queries)} CÂU HỎI ===")

    for i, query in enumerate(queries, 1):
        # ... (phần code trong vòng lặp for của bạn giữ nguyên)
        print(f"\n--- Query {i}/{len(queries)} ---")
        print(f"❓ Câu hỏi: {query}")
    
        context_list = retrieve_context_list(query)
        answer = answer_with_context(query, context_list, knowledge_base) 
        print(f"✅ Câu trả lời của hệ thống: {answer}")
        knowledge_base.append({"question": query, "answer": answer})
        
        generated_data_for_eval.append({
            "question": query,
            "answer": answer,
            "contexts": context_list 
        })
        
        print("-" * 40)
        if i < len(queries):
            print(f"⏳ Đợi {DELAY_BETWEEN_CALLS} giây...")
            time.sleep(DELAY_BETWEEN_CALLS)
    
    print("\n\n✅ Đã thu thập xong toàn bộ dữ liệu (answer, context).")
    display(pd.DataFrame(generated_data_for_eval).head())
    
    output_file = Path('/root/chatbot1/chatbot_document/new_ragas/output_parsing/generated_data_for_eval(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).json')
    output_file.parent.mkdir(parents=True, exist_ok=True)
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(generated_data_for_eval, f, ensure_ascii=False, indent=4)
    print(f"✅ Đã lưu kết quả vào file: {output_file}")


if __name__ == "__main__":
    main()
# Out:
# 🧠 Đang khởi tạo các model
# ✅ Sử dụng thiết bị: cuda
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# ✅ DeepSeek client đã sẵn sàng.
# ✅ ChatGPT OSS client đã sẵn sàng.
# ✅ Reranker model đã sẵn sàng.
# ✅ Các model đã sẵn sàng.
# ✅ Đã xóa collection 'child_chunks_eval_notebook' (nếu tồn tại).
# --- Bước 1: Chuẩn bị dữ liệu Small-to-Big với Qdrant ---
# ✅ Đã tạo 17 parent chunks (đoạn văn lớn).
# ✅ Đã tạo 97 child chunks (câu nhỏ) từ các parent.
# ✅ Đã tạo/tái tạo collection 'child_chunks_eval_notebook' trong Qdrant.
# 🧠 Đang embedding các child chunks...
# ✅ Embedding child chunks hoàn tất!
# ✅ Đã lưu 97 child chunks vào Qdrant.
#
#
# === 🚀 BẮT ĐẦU CHẠY RAG VÀ THU THẬP DỮ LIỆU TRÊN 40 CÂU HỎI ===
#
# --- Query 1/40 ---
# ❓ Câu hỏi: Tên đầy đủ của khách hàng là gì? Chỉ trả về duy nhất cái tên
# ✅ Câu trả lời của hệ thống: CÔNG TY CỔ PHẦN MẶT DỰNG CAG
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 2/40 ---
# ❓ Câu hỏi: Số giấy phép đăng ký kinh doanh của khách hàng là gì? Chỉ trả về duy nhất số giấy phép
# ✅ Câu trả lời của hệ thống: 0101442420
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 3/40 ---
# ❓ Câu hỏi: ID khách hàng là gì? Chỉ trả về duy nhất ID
# ✅ Câu trả lời của hệ thống: 22079986
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 4/40 ---
# ❓ Câu hỏi: Phân khúc của khách hàng là gì? Chỉ trả về duy nhất phân khúc
# ✅ Câu trả lời của hệ thống: MM
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 5/40 ---
# ❓ Câu hỏi: Loại khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Dân dụng; Ngân sách nhà nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 6/40 ---
# ❓ Câu hỏi: Ngành nghề hoạt động kinh doanh của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Ngành nghề hoạt động kinh doanh của khách hàng là **sản xuất và thi công vách kính mặt dựng (cửa sổ, tấm kính mặt dựng) cho các tòa nhà cao tầng**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 7/40 ---
# ❓ Câu hỏi: Mục đích báo cáo là gì?
# ✅ Câu trả lời của hệ thống: Mục đích của báo cáo là trình bày kế hoạch sử dụng vốn vay/tín dụng, đánh giá hiệu quả kinh doanh và tài sản bảo đảm của khách hàng, từ đó đề xuất và xin phê duyệt các hạn mức tín dụng, bảo lãnh, LC và các điều kiện vay tại Techcombank.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 8/40 ---
# ❓ Câu hỏi: Kết quả phân luồng của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Kết quả phân nhóm của khách hàng:
#
# - **Kết quả phân nhóm tiếp cận:** **Khuyến khích**
# - **Phân nhóm rủi ro:** **Rủi ro rất thấp**
# - **Phân nhóm ứng xử KH:** **Nhóm 1**
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 9/40 ---
# ❓ Câu hỏi: XHTD của khách hàng là gì?, XHTD là xếp hạng tín dụng của khách hàng và thường có các giá trị như Aa3, Baa2, v.v. Chỉ trả về duy nhất giá trị xếp hạng tín dụng
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 10/40 ---
# ❓ Câu hỏi: Ngày thành lập công ty là ngày nào? Chỉ trả về duy nhất ngày thành lập
# ✅ Câu trả lời của hệ thống: 19 tháng 01 năm 2004
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 11/40 ---
# ❓ Câu hỏi: Địa chỉ đăng ký kinh doanh của công ty là gì? Chỉ trả về duy nhất địa chỉ đăng ký kinh doanh
# ✅ Câu trả lời của hệ thống: Lô CN4 - 2.1, KCN Thạch Thất, Thị Trấn Quốc Oai, Huyện Quốc Oai, Thành phố Hà Nội, Việt Nam.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 12/40 ---
# ❓ Câu hỏi: Người đại diện theo pháp luật của công ty là ai? Chỉ trả về duy nhất tên người đại diện
# ✅ Câu trả lời của hệ thống: ĐÀO CÔNG DUY
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 13/40 ---
# ❓ Câu hỏi: Khách hàng có kinh doanh ngành nghề có điều kiện không?
# ✅ Câu trả lời của hệ thống: Không, ngành nghề kinh doanh của khách hàng không thuộc các điều kiện không cấp hoặc hạn chế tín dụng; kết quả đánh giá ngành là **Khuyến khích**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 14/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về ban lãnh đạo công ty là gì. Hãy liệt kê đầy đủ tên các thành viên, chức vụ, tỉ lệ góp vốn nếu có?  (Định dạng: Chuỗi JSON chứa một danh sách các đối tượng. Mỗi đối tượng phải có các khóa "ten", "tyLeVon", "chucVu", "mucDoAnhHuong", "danhGia". Nếu không có thông tin về một khóa nào đó, hãy để giá trị là null.
# ✅ Câu trả lời của hệ thống: ```json
# [
#   {
#     "ten": "Đào Công Duy",
#     "tyLeVon": null,
#     "chucVu": "Giám đốc/Tổng giám đốc, Chủ sở hữu chính",
#     "mucDoAnhHuong": null,
#     "danhGia": null
#   },
#   {
#     "ten": "Bà Dung",
#     "tyLeVon": null,
#     "chucVu": "Phó Tổng giám đốc phụ trách tài chính",
#     "mucDoAnhHuong": null,
#     "danhGia": null
#   },
#   {
#     "ten": "Ông Dũng",
#     "tyLeVon": null,
#     "chucVu": "Phó Tổng giám đốc phụ trách kỹ thuật",
#     "mucDoAnhHuong": null,
#     "danhGia": null
#   }
# ]
# ```
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 15/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu vào sản xuất kinh doanh là gì? (Định dạng: Chuỗi JSON với các khóa "matHang", "chiTiet", "pttt". Nếu không có thông tin cho một khóa, hãy dùng giá trị `null`.)
# ✅ Câu trả lời của hệ thống: ```json
# {
#   "matHang": [
#     "Nhôm thanh",
#     "Kính không màu",
#     "Kính màu"
#   ],
#   "chiTiet": "Nhôm thanh được nhập về, cắt theo kích thước khung kính, lắp ráp, bắt vít khung nhôm, bơm keo, đóng gói và chuyển ra công trường. Kính không màu được sản xuất trong nước tại các nhà máy (Thạch Thất, Hà Nội và Đồng Nai). Kính màu không được sản xuất trong nước nên phải nhập khẩu. Công ty có ba nhà máy sản xuất nhôm thanh và kính không màu, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu từ các công ty thương mại.",
#   "pttt": "Sản xuất nội địa (nhôm thanh tiêu chuẩn, kính không màu) kết hợp nhập khẩu (nhôm thanh kích thước lớn, kính màu)."
# }
# ```
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 16/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu ra sản xuất kinh doanh là gì?
# ✅ Câu trả lời của hệ thống: ```json
# {
#   "sanPham": {
#     "moTa": "Sản phẩm vách kính mặt dựng được may đo theo từng dự án (không dùng chung cho dự án khác), vị trí thị trường trung‑cao cấp.",
#     "dacTinh": "Kính 2 lớp: lớp ngoài màu (có lớp chống phản quang) + lớp trong không màu.",
#     "viTriThietKe": "Đáp ứng yêu cầu của khách hàng trong các tòa nhà cao tầng (văn phòng, trung tâm thương mại, tòa nhà hành chính, bệnh viện, v.v.)."
#   },
#   "baoHanh": {
#     "thoiGian": "12‑24 tháng, tùy thuộc hạng của công trình theo quy định của nhà nước."
#   },
#   "chiPhi": {
#     "nguyenVatLieuVaNhanCong": "Khoảng 70 % giá thành (nhôm, kính, nhân công).",
#     "chiPhiKhac": "Khoảng 20 % giá thành.",
#     "mucLoiNhuan": "Mục tiêu lợi nhuận khoảng 10 %."
#   },
#   "khachHang": {
#     "dânDụng": "Các tòa nhà văn phòng, trung tâm thương mại.",
#     "ngânSáchNhàNước": "Các tòa nhà ủy ban, trung tâm hành chính, hội nghị, văn hoá của tỉnh thành.",
#     "nguồnGiaoDịch": "Chủ yếu ký trực tiếp với chủ đầu tư; một số qua tổng thầu và CAG; ít ký hợp đồng với tư cách nhà thầu phụ."
#   },
#   "phanPhoiThiCong": {
#     "doiTuongChinh": "Các dự án của Vingroup, các tổng thầu lớn (Hòa Bình, BIM Group, …), nhà nước (bộ, ban ngành, ACV, TKV, bệnh viện) và Chủ đầu tư tư nhân."
#   }
# }
# ```
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 17/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Khách hàng **CÔNG TY CỔ PHẦN MẶT DỰNG CAG** là doanh nghiệp đã hoạt động từ năm 2004, chuyên sản xuất và thi công vách kính mặt dựng cho các tòa nhà cao tầng. Theo dữ liệu cung cấp:
#
# - **Quy mô và phân khúc:** thuộc phân khúc MM, dịch vụ xây lắp, lắp đặt; xếp hạng tín dụng **Aa3** (rủi ro rất thấp) và được phân nhóm tiếp cận **“Khuyến khích”**.
# - **Cơ cấu sở hữu:** Đào Công Duy chiếm **90 %** vốn, hai cổ đông còn lại nắm **8 %** và **2 %**.
# - **Địa chỉ đăng ký:** Lô CN4‑2.1, KCN Thạch Thất, huyện Quốc Oai, Hà Nội.
# - **Người đại diện pháp luật:** ĐÀO CÔNG DUY (Tổng Giám đốc).
# - **Hoạt động kinh doanh:** sản xuất nội địa nhôm thanh và kính không màu, kết hợp nhập khẩu nhôm thanh kích thước lớn và kính màu; sản phẩm hướng tới thị trường trung‑cao cấp với bảo hành 12‑24 tháng và lợi nhuận mục tiêu khoảng 10 %.
# - **Kết quả đánh giá:** không thuộc nhóm không tiếp cận, duyệt **“Khuyến khích”** và **“Rủi ro rất thấp”**, cho phép đề xuất hạn mức tín dụng và bảo lãnh lớn.
#
# Nhìn chung, CAG là khách hàng ổn định, có năng lực tài chính và tín dụng tốt, phù hợp với các gói vay và bảo lãnh mà Techcombank đề xuất.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 18/40 ---
# ❓ Câu hỏi: Nhận xét về pháp lý/GPKD có điều kiện là gì?
# ✅ Câu trả lời của hệ thống: Không có điều kiện; giấy phép kinh doanh của khách hàng không thuộc danh mục ngành nghề có điều kiện cấp hoặc hạn chế tín dụng.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 19/40 ---
# ❓ Câu hỏi: Nhận xét về chủ doanh nghiệp/ban lãnh đạo là gì?
# ✅ Câu trả lời của hệ thống: Chủ doanh nghiệp là ông Đào Công Duy – đồng sở hữu chính (≈90 % vốn) và giữ chức Giám đốc/Tổng giám đốc. Bên cạnh ông, ban lãnh đạo gồm:
#
# - Bà Dung – Phó Tổng giám đốc phụ trách tài chính (vợ ông Duy).
# - Ông Dũng – Phó Tổng giám đốc phụ trách kỹ thuật (anh trai ông Duy).
# - Hai Phó TGĐ còn lại (chưa có thông tin chi tiết về chức vụ).
#
# Nhận xét:
#
# - **Kinh nghiệm:** Chủ doanh nghiệp có trên 10 năm kinh nghiệm, đáp ứng tiêu chí “Kinh nghiệm của chủ doanh nghiệp ≥10 năm”.
# - **Cấu trúc lãnh đạo:** Được tổ chức theo mô hình Phó TGĐ phụ trách các mảng trọng tâm (tài chính, kỹ thuật), giúp phân quyền và quản lý chuyên môn.
# - **Sự ổn định:** Chủ sở hữu chính nắm quyền quyết định mạnh, hỗ trợ bởi các thành viên gia đình, tạo sự nhất quán trong chiến lược công ty.
# - **Tiềm năng rủi ro:** Thiếu thông tin chi tiết về hai Phó TGĐ còn lại có thể gây hạn chế trong đánh giá toàn diện năng lực quản trị.
#
# Tóm lại, ban lãnh đạo có nền tảng kinh nghiệm và cấu trúc phân công rõ ràng, phù hợp với yêu cầu “Quản trị hiệu quả” và “Quản trị rủi ro” của ngân hàng.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 20/40 ---
# ❓ Câu hỏi: Nhận xét về KYC là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 21/40 ---
# ❓ Câu hỏi: Lĩnh vực kinh doanh của công ty là gì?
# ✅ Câu trả lời của hệ thống: Lĩnh vực kinh doanh của công ty là **sản xuất và thi công vách kính mặt dựng (cửa sổ, tấm kính mặt dựng) cho các tòa nhà cao tầng**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 22/40 ---
# ❓ Câu hỏi: Sản phẩm/dịch vụ của công ty là gì?
# ✅ Câu trả lời của hệ thống: **Sản phẩm / dịch vụ của Công ty Cổ phần Mặt dựng CAG**:
#
# - Hệ thống mặt dựng kính (vách kính mặt dựng, tấm kính mặt dựng, cửa sổ)
# - Tấm ốp Alu
# - Hệ thống cửa kính: cửa tự động, cửa mở quay, cửa đi lùa; cửa sổ mở quay, mở hất
# - Lam chắn nắng và cầu thang kính
#
# (Tất cả đều được thiết kế, sản xuất và thi công theo yêu cầu dự án cho các tòa nhà cao tầng, phục vụ cả khách hàng dân dụng và ngân sách nhà nước.)
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 23/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N-1 (%) là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 24/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N (%) là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 25/40 ---
# ❓ Câu hỏi: Nhóm mặt hàng của công ty là gì?
# ✅ Câu trả lời của hệ thống: Nhóm mặt hàng của công ty bao gồm:
#
# - Hệ thống mặt dựng kính (vách kính, tấm kính mặt dựng)
# - Tấm ốp Alu
# - Hệ thống cửa kính (cửa tự động, cửa mở quay, cửa đi lùa, cửa sổ mở quay, mở hất)
# - Lam chắn nắng
# - Cầu thang kính.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 26/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm 2023 là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 27/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu 10T/2024 là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 28/40 ---
# ❓ Câu hỏi: Mô tả chung về sản phẩm của công ty là gì?
# ✅ Câu trả lời của hệ thống: Công ty chuyên sản xuất và thi công vách kính mặt dựng cùng các sản phẩm liên quan như hệ thống cửa kính, tấm ốp Alu, lam chắn nắng và cầu thang kính. Sản phẩm được thiết kế, may đo theo từng dự án, gồm kính hai lớp (lớp ngoài màu có lớp chống phản quang, lớp trong không màu) và hướng tới phân khúc trung‑cao cấp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 29/40 ---
# ❓ Câu hỏi: Mô tả lợi thế cạnh tranh của công ty là gì?
# ✅ Câu trả lời của hệ thống: **Lợi thế cạnh tranh của Công ty Cổ phần Mặt dựng CAG**
#
# - **Kinh nghiệm lâu năm & uy tín:** Hoạt động từ 2004, đã hoàn thành nhiều dự án lớn (ví dụ: trung tâm chính trị/hành chính mới Hải Phòng – 426 tỷ).
# - **Xếp hạng tín dụng cao:** XHTD **Aa3** → rủi ro rất thấp, được phân nhóm “Khuyến khích”.
# - **Cơ cấu sản xuất tích hợp:** Sản xuất nội địa nhôm thanh và kính không màu, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu; giảm phụ thuộc nguồn cung và kiểm soát chi phí (≈ 70 % chi phí nguyên vật liệu + nhân công).
# - **Thị trường mục tiêu cao cấp:** Sản phẩm vách kính mặt dựng được thiết kế “may đo” cho các tòa nhà trung‑cao cấp, bảo hành 12‑24 tháng, biên lợi nhuận mục tiêu ~10 %.
# - **Đa dạng khách hàng:** Phục vụ cả khách hàng dân dụng (văn phòng, trung tâm thương mại) và ngân sách nhà nước (tòa nhà ủy ban, trung tâm hành chính …), giảm rủi ro tập trung.
# - **Quản trị rủi ro chặt chẽ:** Lựa chọn chủ đầu tư uy tín, theo dõi các hợp đồng có rủi ro dừng thi công; không có khoản dự phòng cần trích lập.
# - **Hợp đồng lớn đang chờ ký:** Doanh số hợp đồng đã ký ~2 000 tỷ, doanh thu dự kiến 2024 >1 000 tỷ, tạo nguồn tiền luân chuyển ổn định.
# - **Ban lãnh đạo ổn định, có kinh nghiệm:** Chủ sở hữu chính (≈ 90 % vốn) – ông Đào Công Duy – kiêm TGĐ, cùng các Phó TGĐ phụ trách tài chính và kỹ thuật, giúp đưa ra quyết định nhanh và tận dụng chuyên môn.
#
# Những yếu tố trên tạo nên khả năng cạnh tranh mạnh mẽ của CAG so với các đối thủ trong lĩnh vực vách kính mặt dựng, đặc biệt là trong phân khúc dự án cao cấp và ngân sách nhà nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 30/40 ---
# ❓ Câu hỏi: Mô tả năng lực đấu thầu của công ty là gì?
# ✅ Câu trả lời của hệ thống: Công ty CAG có năng lực đấu thầu mạnh nhờ:
#
# - **Kinh nghiệm lâu năm**: hơn 20 năm hoạt động trong lĩnh vực vách kính mặt dựng, đã thực hiện nhiều dự án quy mô lớn.
# - **Cơ cấu sản xuất nội bộ**: 3 nhà máy (Hà Nội – Thạch Thất, Đồng Nai) với khả năng sản xuất nhôm thanh và kính không màu, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu, giúp đáp ứng nhanh các yêu cầu kỹ thuật và khối lượng lớn.
# - **Quy mô nhân lực**: khoảng 400 cán bộ nhân viên, tổ chức các phòng ban chuyên môn (tài chính, kế hoạch, thiết kế‑kỹ thuật, kinh doanh‑đấu thầu, XNK) hỗ trợ toàn bộ quy trình đấu thầu và thi công.
# - **Phương thức tham gia**:
#   - Chủ yếu **ký trực tiếp** với chủ đầu tư (dân dụng và ngân sách nhà nước).
#   - Một số trường hợp hợp tác với tổng thầu, trong đó CAG là nhà thầu được chủ đầu tư chỉ định.
#   - Ít ký hợp đồng với tư cách nhà thầu phụ, thể hiện vị thế mạnh trong chuỗi giá trị.
# - **Thành tích dự án**: đã ký các hợp đồng lớn, tiêu biểu như **hợp đồng trung tâm chính trị‑hành chính mới Hải Phòng (426 tỷ VNĐ)**; tổng giá trị hợp đồng đã ký khoảng **2 000 tỷ VNĐ** và dự kiến doanh thu năm 2024 trên **1 000 tỷ VNĐ**.
# - **Tiêu chí lựa chọn dự án**: công ty chỉ tham gia các dự án phù hợp về chất lượng, chủng loại và biên lợi nhuận, tập trung vào phân khúc trung‑cao cấp, giúp duy trì tỷ lệ thắng thầu cao và rủi ro thấp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 31/40 ---
# ❓ Câu hỏi: Quy trình vận hành (tóm tắt) của công ty là gì?
# ✅ Câu trả lời của hệ thống: **Quy trình vận hành (tóm tắt) của Công ty CAG**
#
# 1. **Nhận đơn đặt hàng / ký hợp đồng**
#    - Chủ yếu ký trực tiếp với chủ đầu tư (dân dụng hoặc ngân sách nhà nước) hoặc qua tổng thầu.
#    - Hợp đồng xác định khối lượng, tiến độ và điều kiện thanh toán (thường 20‑30 % tạm ứng, một số dự án 50 %).
#
# 2. **Mua nguyên vật liệu (đầu vào)**
#    - Nhôm thanh và kính không màu được sản xuất nội địa tại 3 nhà máy (Thạch Thất, Hà Nội; Đồng Nai).
#    - Nhôm thanh kích thước lớn và kính màu được nhập khẩu từ các công ty thương mại.
#
# 3. **Sản xuất**
#    - **Cắt** nhôm thanh theo kích thước khung kính.
#    - **Lắp ráp** khung nhôm, **bắt vít** và **bơm keo**.
#    - **Đóng gói** các bộ phận đã lắp ráp.
#
# 4. **Vận chuyển**
#    - Các bộ phận đã đóng gói được chuyển từ nhà máy tới công trường.
#
# 5. **Lắp đặt tại công trường**
#    - Lắp đặt các “unit” đã chuẩn bị sẵn trên bản mã đã định sẵn.
#    - Hoàn thiện vách kính mặt dựng (kính 2 lớp: lớp ngoài màu + lớp chống phản quang, lớp trong không màu).
#
# 6. **Thanh toán**
#    - Thanh toán theo tiến độ thi công và khối lượng hoàn thành.
#    - Một số hợp đồng có công nợ/dở dang kéo dài; công ty quản lý dòng tiền qua tạm ứng và thanh toán định kỳ.
#
# 7. **Bảo hành & hậu mãi**
#    - Bảo hành sản phẩm từ 12‑24 tháng tùy theo hạng công trình, theo quy định của Nhà nước.
#
# **Tóm lại:** quy trình vận hành của CAG bao gồm: nhận hợp đồng → mua và nhập nguyên vật liệu → sản xuất (cắt, lắp ráp, dán keo, đóng gói) → vận chuyển tới công trường → lắp đặt hoàn thiện → thanh toán theo tiến độ → bảo hành. Các bước này được thực hiện bởi ba nhà máy và hỗ trợ bởi bộ phận tài chính, kế hoạch, thiết kế‑kỹ thuật, bán hàng‑đấu thầu và XNK.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 32/40 ---
# ❓ Câu hỏi: Đầu vào - mặt hàng là gì?
# ✅ Câu trả lời của hệ thống: Nhóm mặt hàng đầu vào của công ty gồm: **Nhôm thanh**, **Kính không màu**, **Kính màu**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 33/40 ---
# ❓ Câu hỏi: Đầu vào - chi tiết là gì?
# ✅ Câu trả lời của hệ thống: **Đầu vào – chi tiết**
#
# Nhôm thanh được nhập về, cắt theo kích thước khung kính, lắp ráp, bắt vít khung nhôm, bơm keo, đóng gói và chuyển ra công trường.
# Kính không màu được sản xuất trong nước tại các nhà máy (Thạch Thất, Hà Nội và Đồng Nai).
# Kính màu không được sản xuất trong nước nên phải nhập khẩu.
# Công ty có ba nhà máy sản xuất nhôm thanh và kính không màu, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu từ các công ty thương mại.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 34/40 ---
# ❓ Câu hỏi: Đầu vào - phương thức thanh toán là gì?
# ✅ Câu trả lời của hệ thống: **Phương thức thanh toán đầu vào**
# - **Tạm ứng:** thường từ 20 % – 30 % giá trị hợp đồng (đối với một số dự án có thể lên tới 50 %).
# - **Thanh toán còn lại:** dựa trên tiến độ thi công và khối lượng đã hoàn thành.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 35/40 ---
# ❓ Câu hỏi: Đầu ra - kênh phân phối là gì?
# ✅ Câu trả lời của hệ thống: **Đầu ra – kênh phân phối**
#
# - **Ký trực tiếp với chủ đầu tư** (dân dụng và ngân sách nhà nước).
# - **Ký qua tổng thầu** trong đó CAG được chỉ định làm nhà thầu chính.
# - **Ít ký hợp đồng với tư cách nhà thầu phụ**.
#
# Do đó, kênh phân phối chính của công ty là **bán hàng trực tiếp** và **đi qua tổng thầu**, hướng tới các dự án của các chủ đầu tư lớn (VD: Vingroup, các tổng thầu Hòa Bình, BIM Group, cơ quan nhà nước, và các nhà đầu tư tư nhân).
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 36/40 ---
# ❓ Câu hỏi: Đầu ra - tỷ trọng là bao nhiêu?
# ✅ Câu trả lời của hệ thống: **Đầu ra – tỷ trọng** (theo thông tin doanh thu và chi phí đã cung cấp):
#
# - Chi phí nguyên vật liệu + nhân công: **≈ 70 %** giá thành
# - Chi phí khác: **≈ 20 %** giá thành
# - Biên lợi nhuận mục tiêu: **≈ 10 %** giá thành
#
# (Tổng cộng gần 100 %.)
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 37/40 ---
# ❓ Câu hỏi: Đầu ra - phương thức thanh toán là gì?
# ✅ Câu trả lời của hệ thống: **Đầu ra – phương thức thanh toán**:
# Khách hàng thanh toán dựa trên tiến độ thi công và khối lượng đã hoàn thành. Thông thường:
#
# - **Tạm ứng**: khoảng 20 % – 30 % (đối với một số dự án có thể lên tới 50 %).
# - **Phần còn lại**: thanh toán theo các đợt thanh toán đã thỏa thuận, tương ứng với tiến độ thi công và khối lượng công việc đã giao.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 38/40 ---
# ❓ Câu hỏi: Nhận xét tổng quan về hoạt động kinh doanh là gì?
# ✅ Câu trả lời của hệ thống: Công ty Cổ phần Mặt dựng CAG là doanh nghiệp hoạt động từ năm 2004 trong lĩnh vực sản xuất và thi công vách kính mặt dựng cho các tòa nhà cao tầng. Với 3 nhà máy (2 nhà máy ở Thạch‑Thất, Hà Nội và 1 nhà máy ở Đồng Nai) công ty tự sản xuất nhôm thanh và kính không màu nội địa, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu để hoàn thiện sản phẩm. Quy trình hoạt động bao gồm: nhận đơn đặt hàng → mua nguyên vật liệu → cắt, lắp ráp, bơm keo, đóng gói → vận chuyển tới công trường → lắp đặt → thanh toán theo tiến độ → bảo hành 12‑24 tháng. Sản phẩm được thiết kế “may đo” cho từng dự án, nhắm vào phân khúc trung‑cao cấp (công trình dân dụng và ngân sách nhà nước). Công ty có mô hình bán hàng chủ yếu ký trực tiếp với chủ đầu tư, một phần qua tổng thầu, và ít tham gia làm nhà thầu phụ. Đánh giá tổng thể, CAG có:
#
# - **Quy mô sản xuất tích hợp** và khả năng đáp ứng nhanh nhờ cả nội địa và nhập khẩu.
# - **Thị trường mục tiêu ổn định**, hướng tới các dự án cao cấp và công trình nhà nước, giảm rủi ro tập trung.
# - **Hiệu suất chi phí**: nguyên vật liệu + nhân công chiếm ~70 % giá thành, chi phí khác ~20 %, lợi nhuận mục tiêu ~10 %.
# - **Rủi ro thấp**: xếp hạng tín dụng Aa3, phân nhóm rủi ro “rất thấp”, phân nhóm tiếp cận “khuyến khích”.
# - **Ban lãnh đạo ổn định**, chủ sở hữu chính nắm khoảng 90 % vốn và kiêm TGĐ, hỗ trợ bởi các Phó TGĐ phụ trách tài chính và kỹ thuật.
#
# Như vậy, hoạt động kinh doanh của CAG được đánh giá là ổn định, hiệu quả và tiềm năng, phù hợp với các gói tín dụng và bảo lãnh của ngân hàng.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 39/40 ---
# ❓ Câu hỏi: Phân tích cung cầu ngành là gì?
# ✅ Câu trả lời của hệ thống: **Phân tích cung‑cầu ngành** là việc đánh giá các yếu tố **đầu vào (cung)** và **đầu ra (cầu)** của một ngành kinh doanh, nhằm hiểu mức độ cân bằng, xu hướng tăng/giảm và tiềm năng phát triển của ngành.
#
# ### Trong bối cảnh ngành **vách kính mặt dựng / lắp đặt xây lắp**:
#
# | **Khía cạnh** | **Nội dung** |
# |---------------|--------------|
# | **Cầu (Demand)** | - **Dân dụng:** nhu cầu từ các tòa nhà văn phòng, trung tâm thương mại, dự án căn hộ cao cấp. <br>- **Ngân sách nhà nước:** các dự án ủy ban, trung tâm hành chính, hội nghị, văn hoá của tỉnh‑thành. <br>- **Tăng trưởng:** đô thị hoá, mở rộng quy mô các khu đô thị mới và nâng cấp hạ tầng tạo ra nhu cầu dài hạn cho vách kính mặt dựng. |
# | **Cung (Supply)** | - **Nhà thầu lớn:** chỉ có 3 nhà thầu chính tại VN: **Euro Window, CAG (Công ty Cổ phần Mặt dựng CAG), BM Window** (miền Nam). <br>- **Cấu trúc sản xuất:** CAG tự sản xuất nhôm thanh, kính không màu tại 3 nhà máy, đồng thời nhập khẩu nhôm thanh kích thước lớn và kính màu, giúp đáp ứng nhanh các yêu cầu kỹ thuật và khối lượng lớn. <br>- **Chi phí:** chi phí nguyên vật liệu + nhân công ≈ 70 % giá thành, chi phí khác ≈ 20 %, lợi nhuận mục tiêu ≈ 10 %. |
# | **Cân bằng hiện tại** | - Cung hạn chế (chỉ 3 nhà thầu lớn) so với nhu cầu ngày càng tăng, tạo **cơ hội mở rộng** cho các doanh nghiệp có năng lực sản xuất nội bộ và nhập khẩu linh hoạt (như CAG). <br>- Xếp hạng tín dụng **Aa3** và **rủi ro rất thấp** giúp các nhà thầu này nhận được tài trợ ngân hàng thuận lợi, tăng khả năng đáp ứng nhu cầu thị trường. |
# | **Xu hướng tương lai** | - Tiếp tục tăng nhu cầu **vách kính mặt dựng cao cấp** do xu hướng “trung‑cao cấp” trong bất động sản và các dự án nhà nước. <br>- Áp lực cạnh tranh sẽ tăng nếu các nhà thầu mới gia nhập, nhưng những công ty có chuỗi cung ứng nội bộ và khả năng nhập khẩu linh hoạt sẽ duy trì lợi thế. |
#
# **Tóm lại**, phân tích cung‑cầu ngành giúp nhận diện:
# 1. **Nhu cầu mạnh mẽ** từ cả thị trường dân dụng và ngân sách nhà nước.
# 2. **Cung hạn chế** với vài nhà thầu lớn, trong đó CAG có lợi thế sản xuất tích hợp và xếp hạng tín dụng cao.
# 3. **Cơ hội tăng trưởng** khi tận dụng năng lực nội bộ, nhập khẩu linh hoạt và duy trì tỷ lệ lợi nhuận ổn định.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 40/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin ngành là gì?
# ✅ Câu trả lời của hệ thống: **Ngành hoạt động:** Dịch vụ Xây lắp, lắp đặt (Nhóm Mua NVL – Gia công sản xuất – lắp đặt).
#
# **Nhận xét:** Theo bản đánh giá ngành, tất cả các tiêu chí đều đạt mức **“Khuyến khích”**:
# - Thời gian hoạt động > 5 năm, kinh nghiệm chủ doanh nghiệp ≥ 10 năm.
# - Doanh thu từ ngành ≥ 70 % và doanh thu năm gần nhất ≥ 150 tỷ đồng.
# - Nợ vay/VCSH ≤ 1.5, năng lực thực hiện hợp đồng không có chậm tiến độ.
# - Tỷ trọng doanh thu với nhóm đầu ra chính ≥ 70 %.
#
# Như vậy, ngành được xem là **tiềm năng, ổn định và phù hợp** cho việc cấp tín dụng.
# ----------------------------------------
#
#
# ✅ Đã thu thập xong toàn bộ dữ liệu (answer, context).
#                                             question  \
# 0  Tên đầy đủ của khách hàng là gì? Chỉ trả về du...
# 1  Số giấy phép đăng ký kinh doanh của khách hàng...
# 2        ID khách hàng là gì? Chỉ trả về duy nhất ID
# 3  Phân khúc của khách hàng là gì? Chỉ trả về duy...
# 4                             Loại khách hàng là gì?
#
#                           answer  \
# 0   CÔNG TY CỔ PHẦN MẶT DỰNG CAG
# 1                     0101442420
# 2                       22079986
# 3                             MM
# 4  Dân dụng; Ngân sách nhà nước.
#
#                                             contexts
# 0  [**Kính gửi:** Ngân hàng TMCP Kỹ Thương Việt N...
# 1  [**Kính gửi:** Ngân hàng TMCP Kỹ Thương Việt N...
# 2  [**Kính gửi:** Ngân hàng TMCP Kỹ Thương Việt N...
# 3  [---\n# File 3: Báo cáo hỗ trợ phân nhóm KH - ...
# 4  [---\n# File 3: Báo cáo hỗ trợ phân nhóm KH - ...
# ✅ Đã lưu kết quả vào file: /root/chatbot1/new_ragas/output_parsing/generated_data_for_eval(full_raw_input_gemini2.5_parsing_chatoss).json

# %% [markdown]
# # RAGAS Evaluation

# %%
from ragas_evaluation import RagasEvaluator
import pandas as pd
from pathlib import Path
import json

# 1. Khởi tạo Evaluator
evaluator = RagasEvaluator(list_of_api_keys=LIST_GOOGLE_API_KEYS)

# Load generated data từ file JSON: (generated data is RAG output: question, LLM answer, context)
generated_data_file = Path('/root/chatbot1/chatbot_document/new_ragas/output_parsing/generated_data_for_eval(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).json')
if not generated_data_file.exists():
    print(f"❌ Lỗi: Không tìm thấy file {generated_data_file}. Vui lòng chạy bước thu thập dữ liệu trước.")
else:
    with open(generated_data_file, 'r', encoding='utf-8') as f:
        generated_data_for_eval = json.load(f)
        
# 2.  Load base data (chứa question và ground_truth)
base_data = evaluator.load_base_dataset(Path('/root/chatbot1/chatbot_document/new_ragas/schemas/ragasdf_base.json'))

# 3. Chuẩn bị dataset hoàn chỉnh bằng cách kết hợp base_data và generated_data
'''
Evaluation dataset includes:
- question
- ground_truth (optional but need for some metrics: answer_correctness)
- contexts (list of context strings)
- answer (LLM generated answer)
'''
eval_dataset = evaluator.prepare_evaluation_dataset(
    base_data=base_data,
    generated_data=generated_data_for_eval 
)
    

# 4. Xuất file dataset RAGAS hoàn chỉnh ra Excel để kiểm tra
if eval_dataset:
    ragas_df = eval_dataset.to_pandas()
    ragas_df['context_count'] = ragas_df['contexts'].apply(len)
    output_df_path = "/root/chatbot1/chatbot_document/new_ragas/ragasdf/ragas_dataset_for_evaluation(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).xlsx"
    ragas_df.to_excel(output_df_path, index=False)
    print(f"💾 Đã xuất file dataset RAGAS hoàn chỉnh ra: {output_df_path}")
    
# 5. Chạy đánh giá
if eval_dataset:
    results_df = evaluator.run_evaluation(eval_dataset)

    if results_df is not None:
        report_dir = "/root/chatbot1/chatbot_document/new_ragas/evaluation_reports"
        report_filename = "ragas_report(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).xlsx"
        saved_path = evaluator.save_report(results_df, output_dir=report_dir, filename=report_filename)
        if saved_path:
            print(f"✅ Báo cáo đã được lưu tại: {saved_path}")
        else:
            print("❌ Không thể lưu báo cáo.")
        # evaluator.display_evaluation_cost()
    else:
        print("❌ Đánh giá không trả về kết quả.")
else:
    print("❌ Không thể tạo dataset để đánh giá.")
# Out:
# 🚀 Khởi tạo RagasEvaluator (có Retry & Key Switching)...
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# LLM và Embeddings đã sẵn sàng.
# 📋 Đã định nghĩa 5 metrics: ['faithfulness', 'context_precision', 'context_recall', 'answer_correctness', 'semantic_similarity']
# Đã tạo thư mục báo cáo: evaluation_reports
# Đang tải base dataset từ: /root/chatbot1/new_ragas/schemas/ragasdf_base.json
# Tải thành công 40 mẫu.
# Đang chuẩn bị dataset để đánh giá...
# Đã chuẩn hóa cột 'contexts' với kiểu dữ liệu: <class 'list'>
# Đã tạo thành công dataset với 40 mẫu để đánh giá.
# Kiểu dữ liệu của cột 'contexts' đã được xác nhận là: <class 'list'>
# Sau khi loại bỏ null/empty, còn 15 mẫu.
# Đã thêm cột 'reference' từ ground_truths.
# 💾 Đã xuất file dataset RAGAS hoàn chỉnh ra: /root/chatbot1/new_ragas/ragasdf/ragas_dataset_for_evaluation(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).xlsx
# Dataset schema hợp lệ. Columns: ['question', 'ground_truths', 'answer', 'contexts', 'reference', '__index_level_0__']
#
# 🔬 Bắt đầu đánh giá RAGAS trên 15 mẫu với 5 metrics...
# 📋 Metrics: ['faithfulness', 'context_precision', 'context_recall', 'answer_correctness', 'semantic_similarity']
#
# --- 🔄 Đang đánh giá dòng 1/15 ---
#    Q: Tên đầy đủ của khách hàng là gì? Chỉ trả về duy nhất cái tên...
#    A: CÔNG TY CỔ PHẦN MẶT DỰNG CAG...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 1.0000
# ✅ Đánh giá dòng 1 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 2/15 ---
#    Q: Số giấy phép đăng ký kinh doanh của khách hàng là gì? Chỉ trả về duy nhất số giấy phép...
#    A: 0101442420...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 1.0000
# ✅ Đánh giá dòng 2 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 3/15 ---
#    Q: ID khách hàng là gì? Chỉ trả về duy nhất ID...
#    A: 22079986...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 1.0000
# ✅ Đánh giá dòng 3 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 4/15 ---
#    Q: Phân khúc của khách hàng là gì? Chỉ trả về duy nhất phân khúc...
#    A: MM...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 1.0000
# ✅ Đánh giá dòng 4 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 5/15 ---
#    Q: XHTD của khách hàng là gì?, XHTD là xếp hạng tín dụng của khách hàng và thường có các giá trị như Aa...
#    A: Tôi không tìm thấy thông tin trong tài liệu....
#     🔄 Metric 1/5: faithfulness
#     Score: 0.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 0.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 0.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.1036
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.4144
# ✅ Đánh giá dòng 5 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 6/15 ---
#    Q: Ngày thành lập công ty là ngày nào? Chỉ trả về duy nhất ngày thành lập...
#    A: 19 tháng 01 năm 2004...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.9753
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.9012
# ✅ Đánh giá dòng 6 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 7/15 ---
#    Q: Địa chỉ đăng ký kinh doanh của công ty là gì? Chỉ trả về duy nhất địa chỉ đăng ký kinh doanh...
#    A: Lô CN4 - 2.1, KCN Thạch Thất, Thị Trấn Quốc Oai, Huyện Quốc Oai, Thành phố Hà Nội, Việt Nam....
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.9948
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.9791
# ✅ Đánh giá dòng 7 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 8/15 ---
#    Q: Người đại diện theo pháp luật của công ty là ai? Chỉ trả về duy nhất tên người đại diện...
#    A: ĐÀO CÔNG DUY...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 1.0000
# ✅ Đánh giá dòng 8 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 9/15 ---
#    Q: Khách hàng có kinh doanh ngành nghề có điều kiện không?...
#    A: Không, ngành nghề kinh doanh của khách hàng không thuộc các điều kiện không cấp hoặc hạn chế tín dụn...
#     🔄 Metric 1/5: faithfulness
#     Score: 0.6667
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 0.5833
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 0.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.1047
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.4189
# ✅ Đánh giá dòng 9 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 10/15 ---
#    Q: Thông tin chi tiết về ban lãnh đạo công ty là gì. Hãy liệt kê đầy đủ tên các thành viên, chức vụ, tỉ...
#    A: ```json
# [
#   {
#     "ten": "Đào Công Duy",
#     "tyLeVon": null,
#     "chucVu": "Giám đốc/Tổng giám đốc,...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 0.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.7201
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.8803
# ✅ Đánh giá dòng 10 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 11/15 ---
#    Q: Thông tin chi tiết về đầu vào sản xuất kinh doanh là gì? (Định dạng: Chuỗi JSON với các khóa "matHan...
#    A: ```json
# {
#   "matHang": [
#     "Nhôm thanh",
#     "Kính không màu",
#     "Kính màu"
#   ],
#   "chiTiet": "N...
#     🔄 Metric 1/5: faithfulness
#     Score: 0.7143
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 0.6667
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.6038
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.8153
# ✅ Đánh giá dòng 11 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 12/15 ---
#    Q: Lĩnh vực kinh doanh của công ty là gì?...
#    A: Lĩnh vực kinh doanh của công ty là **sản xuất và thi công vách kính mặt dựng (cửa sổ, tấm kính mặt d...
#     🔄 Metric 1/5: faithfulness
#     Score: 0.2500
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 0.8333
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.1400
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.5599
# ✅ Đánh giá dòng 12 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 13/15 ---
#    Q: Sản phẩm/dịch vụ của công ty là gì?...
#    A: **Sản phẩm / dịch vụ của Công ty Cổ phần Mặt dựng CAG**:
#
# - Hệ thống mặt dựng kính (vách kính mặt dự...
#     🔄 Metric 1/5: faithfulness
#     Score: 0.6667
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.5943
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.7982
# ✅ Đánh giá dòng 13 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 14/15 ---
#    Q: Đầu vào - mặt hàng là gì?...
#    A: Nhóm mặt hàng đầu vào của công ty gồm: **Nhôm thanh**, **Kính không màu**, **Kính màu**....
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.4452
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.5810
# ✅ Đánh giá dòng 14 hoàn tất.
#
# --- 🔄 Đang đánh giá dòng 15/15 ---
#    Q: Đầu vào - chi tiết là gì?...
#    A: **Đầu vào – chi tiết**
#
# Nhôm thanh được nhập về, cắt theo kích thước khung kính, lắp ráp, bắt vít kh...
#     🔄 Metric 1/5: faithfulness
#     Score: 1.0000
#     Chờ 1s...
#     🔄 Metric 2/5: context_precision
#     Score: 0.5000
#     Chờ 1s...
#     🔄 Metric 3/5: context_recall
#     Score: 0.5000
#     Chờ 1s...
#     🔄 Metric 4/5: answer_correctness
#     Score: 0.4720
#     Chờ 1s...
#     🔄 Metric 5/5: semantic_similarity
#     Score: 0.7970
# ✅ Đánh giá dòng 15 hoàn tất.
# Đã đảm bảo thư mục tồn tại: /root/chatbot1/new_ragas/evaluation_reports
# Tìm thấy 5 metrics trong kết quả: ['faithfulness', 'context_precision', 'context_recall', 'answer_correctness', 'semantic_similarity']
# Báo cáo đã được lưu tại: /root/chatbot1/new_ragas/evaluation_reports/ragas_report(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).xlsx
# Điểm số trung bình:
#    faithfulness: 0.8198
#    context_precision: 0.8611
#    context_recall: 0.7444
#    answer_correctness: 0.6769
#    semantic_similarity: 0.8097
# ✅ Báo cáo đã được lưu tại: /root/chatbot1/new_ragas/evaluation_reports/ragas_report(full_raw_input_gemini2.5_parsing_chatoss_eval_deepseek).xlsx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 54
#      52     else:
#      53         print("❌ Không thể lưu báo cáo.")
# ---> 54     evaluator.display_evaluation_cost()
#      55 else:
#      56     print("❌ Đánh giá không trả về kết quả.")
#
# AttributeError: 'RagasEvaluator' object has no attribute 'display_evaluation_cost'

# %% [markdown]
# # RAGAS Evaluation (ChatGPT OSS 120B)
