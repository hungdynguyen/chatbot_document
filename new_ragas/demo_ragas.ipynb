# %% [markdown]
# # Full Flow Advanced RAG + Get Context

# %%
import os
import time
import shutil

os.system("docker rm -f qdrant-container > /dev/null 2>&1")

print("\n🐳 Đang khởi động container Qdrant mới...")
os.system("""
docker run -d \
    --name qdrant-container \
    -p 6333:6333 \
    -p 6334:6334 \
    -v "$(pwd)/qdrant_storage:/qdrant/storage:z" \
    qdrant/qdrant:latest
""")
print("✅ Qdrant đã sẵn sàng. Chờ 2 giây để khởi động hoàn tất...")
time.sleep(2)
# Out:
# 🐳 Đang khởi động container Qdrant mới...
# 7c56f3c6ece20c175532e932476baf7a5e1b67bcc305dfa6e910ccb669a0706d
# ✅ Qdrant đã sẵn sàng. Chờ 2 giây để khởi động hoàn tất...

# %%
# IMPORT PACKAGES
import os
import json
from pathlib import Path
from typing import List, Tuple
import time
import uuid
import numpy as np
import pandas as pd
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from sentence_transformers import CrossEncoder
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams, PointStruct
from langchain_openai import ChatOpenAI 
from config import (
    DEEPSEEK_API_KEY,
    QDRANT_HOST,
    QDRANT_PORT,
    COLLECTION_NAME,
    DELAY_BETWEEN_CALLS,
    EMBEDDING_MODEL_NAME,
    EMBEDDING_DEVICE,
    LIST_GOOGLE_API_KEYS,
    RERANKER_MODEL_NAME,
    RERANKER_DEVICE
)
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings(
    "ignore", 
    message="flash_attn is not installed. Using PyTorch native attention implementation."
)

# %%
# --- KHỞI TẠO CÁC MODEL ---
print("🧠 Đang khởi tạo các model")

# Embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL_NAME,
    model_kwargs={"device": EMBEDDING_DEVICE, "trust_remote_code": True}
)

# LLM
try:
    deepseek_llm_client = ChatOpenAI(
        model="deepseek-chat",
        api_key=DEEPSEEK_API_KEY,
        base_url="https://api.deepseek.com/v1",
        temperature=0.3,    
    )
    print("✅ DeepSeek client đã sẵn sàng.")
except Exception as e:
    print(f"❌ Lỗi khi khởi tạo DeepSeek client: {e}")
    deepseek_llm_client = None
    
# Reranker model
reranker_model = CrossEncoder(model_name_or_path= RERANKER_MODEL_NAME,
                              device=RERANKER_DEVICE,
                              trust_remote_code=True)
print("✅ Reranker model đã sẵn sàng.")
qdrant_client = QdrantClient(host=QDRANT_HOST, port=QDRANT_PORT)
print("✅ Các model đã sẵn sàng.")

# Clear previous collection of Qdrant if exists
def clear_qdrant_collection():
    """Xóa collection để đảm bảo dữ liệu mới mỗi lần chạy."""
    try:
        qdrant_client.delete_collection(collection_name=COLLECTION_NAME)
        print(f"✅ Đã xóa collection '{COLLECTION_NAME}' (nếu tồn tại).")
    except Exception:
        pass 
# Setup Qdrant collection 
def setup_qdrant_collection(embedding_dim: int):
    """Tạo hoặc tái tạo collection trong Qdrant."""
    try:
        qdrant_client.recreate_collection(
            collection_name=COLLECTION_NAME,
            vectors_config=VectorParams(size=embedding_dim, distance=Distance.COSINE)
        )
        print(f"✅ Đã tạo/tái tạo collection '{COLLECTION_NAME}' trong Qdrant.")
        return True
    except Exception as e:
        print(f"❌ Lỗi khi setup Qdrant collection: {e}")
        return False

# Store chunks in Qdrant
def store_child_chunks_in_qdrant(child_chunks: List[Document], child_embeddings: np.ndarray):
    """Lưu child chunks và embeddings vào Qdrant."""
    points = []
    for chunk, emb in zip(child_chunks, child_embeddings):
        payload = {
            "content": chunk.page_content,
            "parent_id": chunk.metadata.get("parent_id"),
            "parent_content": chunk.metadata.get("parent_content"),
            "source": chunk.metadata.get("source", "unknown")
        }
        points.append(PointStruct(id=str(uuid.uuid4()), vector=emb.tolist(), payload=payload))
    qdrant_client.upsert(collection_name=COLLECTION_NAME, points=points, wait=True)
    print(f"✅ Đã lưu {len(points)} child chunks vào Qdrant.")

# Parent - Child chunking strategy and Embedding in Qdrant
def setup_small_to_big_data_with_qdrant(markdown_content: str):
    """Chuẩn bị dữ liệu cho chiến lược Small-to-Big và lưu vào Qdrant."""
    print("--- Bước 1: Chuẩn bị dữ liệu Small-to-Big với Qdrant ---")
    parent_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=200)
    child_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=50)
    parent_chunks = parent_splitter.create_documents([markdown_content])
    print(f"✅ Đã tạo {len(parent_chunks)} parent chunks (đoạn văn lớn).")

    all_child_chunks = []
    for i, p_chunk in enumerate(parent_chunks):
        child_texts = child_splitter.split_text(p_chunk.page_content)
        for text in child_texts:
            all_child_chunks.append(Document(page_content=text, metadata={"parent_id": i, "parent_content": p_chunk.page_content}))
    print(f"✅ Đã tạo {len(all_child_chunks)} child chunks (câu nhỏ) từ các parent.")
            
    sample_embedding = embedding_model.embed_query("test")
    if not setup_qdrant_collection(len(sample_embedding)): 
        return None, False
    
    print("🧠 Đang embedding các child chunks...")
    child_contents = [c.page_content for c in all_child_chunks]
    child_embeddings = np.array(embedding_model.embed_documents(child_contents))
    print("✅ Embedding child chunks hoàn tất!")
    
    store_child_chunks_in_qdrant(all_child_chunks, child_embeddings)
    return parent_chunks, True

def retrieve_context_list(query: str, top_k_final: int = 3, retrieve_k_children: int = 15) -> List[str]:
    """
    Pipeline RAG: Search child chunks --> Mapping parents --> Reranking parents --> Return top-k parents.
    """
    query_embedding = embedding_model.embed_query(query)
    search_results = qdrant_client.search(collection_name=COLLECTION_NAME, query_vector=query_embedding, limit=retrieve_k_children, with_payload=True)
    
    candidate_parents = {hit.payload["parent_content"] for hit in search_results if hit.payload and "parent_content" in hit.payload}
    
    if not candidate_parents: return [] 
    
    parent_contents = list(candidate_parents)
    pairs = [(query, content) for content in parent_contents]
    scores = reranker_model.predict(pairs)
    reranked_results = sorted(zip(scores, parent_contents), key=lambda x: x[0], reverse=True)
    
    final_docs = [content for _, content in reranked_results[:top_k_final]]
    return final_docs
    
def answer_with_context(query: str, context_list: List[str]) -> str: 
    """Sử dụng LLM để trả lời câu hỏi dựa trên context được cung cấp."""
    
    full_context_str = "\n\n---\n\n".join(context_list)
    
    prompt_template = f"""Bạn là một trợ lý AI chuyên nghiệp, chỉ trả lời dựa trên context được cung cấp.
    Trả lời câu hỏi một cách ngắn gọn và chính xác. Nếu không có thông tin trong context, hãy nói "Tôi không tìm thấy thông tin trong tài liệu."

    Context:
    ---
    {full_context_str}
    ---
    

    Câu hỏi: {query}

    Trả lời:
    """
    response = deepseek_llm_client.invoke(prompt_template)
    return response.content

# --- CHẠY PIPELINE VÀ THU THẬP DỮ LIỆU ---

def main():
    """
    Hàm chính để thực thi toàn bộ pipeline RAG và đánh giá.
    """
    generated_data_for_eval = [] 
    markdown_file_path = Path("/root/chatbot1/chatbot_document/backend/output_parsing/parsed_output.md")

    if not markdown_file_path.exists():
        print(f"❌ Lỗi: Không tìm thấy file {markdown_file_path}. Vui lòng chạy bước parsing trước.")
        return 

    with open(markdown_file_path, 'r', encoding='utf-8') as f:
        markdown_content = f.read()

    clear_qdrant_collection()
    parent_chunks, success = setup_small_to_big_data_with_qdrant(markdown_content)
    
    if not success:
        print("❌ Không thể setup dữ liệu với Qdrant. Dừng chương trình.")
        return 

    # Lấy câu hỏi từ file ragasdf_base.json
    with open(Path("backend/schemas/ragasdf_base.json"), 'r', encoding='utf-8') as f:
        queries_data = json.load(f)
    queries = [item['question'] for item in queries_data]

    print(f"\n\n=== 🚀 BẮT ĐẦU CHẠY RAG VÀ THU THẬP DỮ LIỆU TRÊN {len(queries)} CÂU HỎI ===")

    for i, query in enumerate(queries, 1):
        # ... (phần code trong vòng lặp for của bạn giữ nguyên)
        print(f"\n--- Query {i}/{len(queries)} ---")
        print(f"❓ Câu hỏi: {query}")
        
        context_list = retrieve_context_list(query)
        answer = answer_with_context(query, context_list) 
        print(f"✅ Câu trả lời của hệ thống: {answer}")
        
        generated_data_for_eval.append({
            "question": query,
            "answer": answer,
            "contexts": context_list 
        })
        
        print("-" * 40)
        if i < len(queries):
            print(f"⏳ Đợi {DELAY_BETWEEN_CALLS} giây...")
            time.sleep(DELAY_BETWEEN_CALLS)
    
    print("\n\n✅ Đã thu thập xong toàn bộ dữ liệu (answer, context).")
    display(pd.DataFrame(generated_data_for_eval).head())
    
    output_file = Path('/root/chatbot1/new_ragas/output_parsing/generated_data_for_eval(full_raw_input_deepseek).json')
    output_file.parent.mkdir(parents=True, exist_ok=True)
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(generated_data_for_eval, f, ensure_ascii=False, indent=4)
    print(f"✅ Đã lưu kết quả vào file: {output_file}")


if __name__ == "__main__":
    main()
# Out:
# 🧠 Đang khởi tạo các model
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# ✅ DeepSeek client đã sẵn sàng.
# ✅ Reranker model đã sẵn sàng.
# ✅ Các model đã sẵn sàng.
# ✅ Đã xóa collection 'child_chunks_eval_notebook' (nếu tồn tại).
# --- Bước 1: Chuẩn bị dữ liệu Small-to-Big với Qdrant ---
# ✅ Đã tạo 19 parent chunks (đoạn văn lớn).
# ✅ Đã tạo 102 child chunks (câu nhỏ) từ các parent.
# ✅ Đã tạo/tái tạo collection 'child_chunks_eval_notebook' trong Qdrant.
# 🧠 Đang embedding các child chunks...
# ✅ Reranker model đã sẵn sàng.
# ✅ Các model đã sẵn sàng.
# ✅ Đã xóa collection 'child_chunks_eval_notebook' (nếu tồn tại).
# --- Bước 1: Chuẩn bị dữ liệu Small-to-Big với Qdrant ---
# ✅ Đã tạo 19 parent chunks (đoạn văn lớn).
# ✅ Đã tạo 102 child chunks (câu nhỏ) từ các parent.
# ✅ Đã tạo/tái tạo collection 'child_chunks_eval_notebook' trong Qdrant.
# 🧠 Đang embedding các child chunks...
# ✅ Embedding child chunks hoàn tất!
# ✅ Đã lưu 102 child chunks vào Qdrant.
#
#
# === 🚀 BẮT ĐẦU CHẠY RAG VÀ THU THẬP DỮ LIỆU TRÊN 40 CÂU HỎI ===
#
# --- Query 1/40 ---
# ❓ Câu hỏi: Tên đầy đủ của khách hàng là gì?
# ✅ Embedding child chunks hoàn tất!
# ✅ Đã lưu 102 child chunks vào Qdrant.
#
#
# === 🚀 BẮT ĐẦU CHẠY RAG VÀ THU THẬP DỮ LIỆU TRÊN 40 CÂU HỎI ===
#
# --- Query 1/40 ---
# ❓ Câu hỏi: Tên đầy đủ của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Tên đầy đủ của khách hàng là: CÔNG TY CỔ PHẦN MẶT DỰNG CAG.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tên đầy đủ của khách hàng là: CÔNG TY CỔ PHẦN MẶT DỰNG CAG.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 2/40 ---
# ❓ Câu hỏi: Số giấy phép đăng ký kinh doanh của khách hàng là gì?
#
# --- Query 2/40 ---
# ❓ Câu hỏi: Số giấy phép đăng ký kinh doanh của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Số giấy phép đăng ký kinh doanh của khách hàng là 0101442420.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Số giấy phép đăng ký kinh doanh của khách hàng là 0101442420.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 3/40 ---
# ❓ Câu hỏi: ID khách hàng là gì?
#
# --- Query 3/40 ---
# ❓ Câu hỏi: ID khách hàng là gì?
# ✅ Câu trả lời của hệ thống: ID khách hàng là **22079986**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: ID khách hàng là **22079986**.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 4/40 ---
# ❓ Câu hỏi: Phân khúc của khách hàng là gì?
#
# --- Query 4/40 ---
# ❓ Câu hỏi: Phân khúc của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Phân khúc khách hàng của các doanh nghiệp trong ngành bao gồm:
# - **Dân dụng**: các tòa nhà văn phòng, trung tâm thương mại.
# - **Ngân sách nhà nước**: các tòa nhà ủy ban, trung tâm hành chính, hội nghị, văn hóa của các tỉnh/thành phố.
# - **CĐT tư nhân**: các dự án lớn như Vingroup, tổng thầu (Hòa Bình, BIM group), hoặc dự án ngoài nước (BM Windows).
#
# Một số doanh nghiệp (như CAG, Eurowindow) còn phục vụ các bệnh viện, cảng hàng không (ACV), hoặc ngành than (TKV).
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Phân khúc khách hàng của các doanh nghiệp trong ngành bao gồm:
# - **Dân dụng**: các tòa nhà văn phòng, trung tâm thương mại.
# - **Ngân sách nhà nước**: các tòa nhà ủy ban, trung tâm hành chính, hội nghị, văn hóa của các tỉnh/thành phố.
# - **CĐT tư nhân**: các dự án lớn như Vingroup, tổng thầu (Hòa Bình, BIM group), hoặc dự án ngoài nước (BM Windows).
#
# Một số doanh nghiệp (như CAG, Eurowindow) còn phục vụ các bệnh viện, cảng hàng không (ACV), hoặc ngành than (TKV).
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 5/40 ---
# ❓ Câu hỏi: Loại khách hàng là gì?
#
# --- Query 5/40 ---
# ❓ Câu hỏi: Loại khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Loại khách hàng của CÔNG TY CỔ PHẦN MẶT DỰNG CAG là:
# - NSNN: Bộ ban ngành, ACV, TKV, bệnh viện
# - CĐT tư nhân
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Loại khách hàng của CÔNG TY CỔ PHẦN MẶT DỰNG CAG là:
# - NSNN: Bộ ban ngành, ACV, TKV, bệnh viện
# - CĐT tư nhân
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 6/40 ---
# ❓ Câu hỏi: Ngành nghề hoạt động kinh doanh của khách hàng là gì?
#
# --- Query 6/40 ---
# ❓ Câu hỏi: Ngành nghề hoạt động kinh doanh của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Ngành nghề hoạt động kinh doanh của khách hàng là sản xuất và thi công các sản phẩm nhôm kính, bao gồm vách kính mặt dựng, cửa nhôm, cabin tắm, lan can kính, và các hệ thống cửa khác (tự động, cuốn, nhựa uPVC). Khách hàng cũng tham gia vào các dự án xây dựng cao tầng, trung tâm thương mại, công trình công cộng và dân dụng.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Ngành nghề hoạt động kinh doanh của khách hàng là sản xuất và thi công các sản phẩm nhôm kính, bao gồm vách kính mặt dựng, cửa nhôm, cabin tắm, lan can kính, và các hệ thống cửa khác (tự động, cuốn, nhựa uPVC). Khách hàng cũng tham gia vào các dự án xây dựng cao tầng, trung tâm thương mại, công trình công cộng và dân dụng.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 7/40 ---
# ❓ Câu hỏi: Mục đích báo cáo là gì?
#
# --- Query 7/40 ---
# ❓ Câu hỏi: Mục đích báo cáo là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 8/40 ---
# ❓ Câu hỏi: Kết quả phân luồng của khách hàng là gì?
#
# --- Query 8/40 ---
# ❓ Câu hỏi: Kết quả phân luồng của khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 9/40 ---
# ❓ Câu hỏi: XHTD của khách hàng là gì?, XHTD là xếp hạng tín dụng của khách hàng và thường có các giá trị như Aa3, Baa2, v.v.
#
# --- Query 9/40 ---
# ❓ Câu hỏi: XHTD của khách hàng là gì?, XHTD là xếp hạng tín dụng của khách hàng và thường có các giá trị như Aa3, Baa2, v.v.
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 10/40 ---
# ❓ Câu hỏi: Ngày thành lập công ty là ngày nào?
#
# --- Query 10/40 ---
# ❓ Câu hỏi: Ngày thành lập công ty là ngày nào?
# ✅ Câu trả lời của hệ thống: Ngày thành lập công ty là ngày 19 tháng 01 năm 2004.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Ngày thành lập công ty là ngày 19 tháng 01 năm 2004.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 11/40 ---
# ❓ Câu hỏi: Địa chỉ đăng ký kinh doanh của công ty là gì?
#
# --- Query 11/40 ---
# ❓ Câu hỏi: Địa chỉ đăng ký kinh doanh của công ty là gì?
# ✅ Câu trả lời của hệ thống: Lô CN4 - 2.1, KCN Thạch Thất, Thị Trấn Quốc Oai, Huyện Quốc Oai, Thành phố Hà Nội, Việt Nam
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Lô CN4 - 2.1, KCN Thạch Thất, Thị Trấn Quốc Oai, Huyện Quốc Oai, Thành phố Hà Nội, Việt Nam
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 12/40 ---
# ❓ Câu hỏi: Người đại diện theo pháp luật của công ty là ai?
#
# --- Query 12/40 ---
# ❓ Câu hỏi: Người đại diện theo pháp luật của công ty là ai?
# ✅ Câu trả lời của hệ thống: Người đại diện theo pháp luật của công ty là Đào Công Duy, chức danh Tổng giám đốc.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Người đại diện theo pháp luật của công ty là Đào Công Duy, chức danh Tổng giám đốc.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 13/40 ---
# ❓ Câu hỏi: Khách hàng có kinh doanh ngành nghề có điều kiện không?
#
# --- Query 13/40 ---
# ❓ Câu hỏi: Khách hàng có kinh doanh ngành nghề có điều kiện không?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 14/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về ban lãnh đạo công ty là gì. Hãy liệt kê đầy đủ tên các thành viên, chức vụ, tỉ lệ góp vốn nếu có?
#
# --- Query 14/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về ban lãnh đạo công ty là gì. Hãy liệt kê đầy đủ tên các thành viên, chức vụ, tỉ lệ góp vốn nếu có?
# ✅ Câu trả lời của hệ thống: Thông tin ban lãnh đạo công ty từ context:
#
# 1. **Đào Công Duy**
#    - Chức vụ: Tổng giám đốc
#    - Tỷ lệ góp vốn: 90%
#    - CCCD: 034067001074
#
# 2. **Thái Thị Kim Dung**
#    - Tỷ lệ góp vốn: 8%
#    - CCCD: 040174000053
#
# 3. **Đào Công Dũng**
#    - Tỷ lệ góp vốn: 2%
#    - CMND: 017368377
#
# *Lưu ý: Context không cung cấp chức vụ cụ thể của Thái Thị Kim Dung và Đào Công Dũng.*
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Thông tin ban lãnh đạo công ty từ context:
#
# 1. **Đào Công Duy**
#    - Chức vụ: Tổng giám đốc
#    - Tỷ lệ góp vốn: 90%
#    - CCCD: 034067001074
#
# 2. **Thái Thị Kim Dung**
#    - Tỷ lệ góp vốn: 8%
#    - CCCD: 040174000053
#
# 3. **Đào Công Dũng**
#    - Tỷ lệ góp vốn: 2%
#    - CMND: 017368377
#
# *Lưu ý: Context không cung cấp chức vụ cụ thể của Thái Thị Kim Dung và Đào Công Dũng.*
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 15/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu vào sản xuất kinh doanh là gì?
#
# --- Query 15/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu vào sản xuất kinh doanh là gì?
# ✅ Câu trả lời của hệ thống: Thông tin chi tiết về đầu vào sản xuất kinh doanh bao gồm:
#
# 1. **Nhôm thanh**:
#    - Các mã kích thước nhỏ: có thể nhập hàng sản xuất trong nước.
#    - Các mã kích thước lớn: trong nước không sản xuất được, phải nhập khẩu từ Trung Quốc.
#
# 2. **Phôi kính**:
#    - Với hàng nhập khẩu, công ty thường mua thông qua các đơn vị chuyên nhập phôi kính do nhập khẩu trực tiếp không đáp ứng về chi phí và tiến độ.
#    - Kính không màu: có thể nhập hàng sản xuất trong nước.
#
# Ngoài ra, công ty còn sử dụng các công ty thương mại chuyên nhập khẩu nhôm thanh (các mã kích thước lớn) và kính màu (trong nước chưa sản xuất được).
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Thông tin chi tiết về đầu vào sản xuất kinh doanh bao gồm:
#
# 1. **Nhôm thanh**:
#    - Các mã kích thước nhỏ: có thể nhập hàng sản xuất trong nước.
#    - Các mã kích thước lớn: trong nước không sản xuất được, phải nhập khẩu từ Trung Quốc.
#
# 2. **Phôi kính**:
#    - Với hàng nhập khẩu, công ty thường mua thông qua các đơn vị chuyên nhập phôi kính do nhập khẩu trực tiếp không đáp ứng về chi phí và tiến độ.
#    - Kính không màu: có thể nhập hàng sản xuất trong nước.
#
# Ngoài ra, công ty còn sử dụng các công ty thương mại chuyên nhập khẩu nhôm thanh (các mã kích thước lớn) và kính màu (trong nước chưa sản xuất được).
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 16/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu ra sản xuất kinh doanh là gì?
#
# --- Query 16/40 ---
# ❓ Câu hỏi: Thông tin chi tiết về đầu ra sản xuất kinh doanh là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 17/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin khách hàng là gì?
#
# --- Query 17/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin khách hàng là gì?
# ✅ Câu trả lời của hệ thống: Thông tin khách hàng là CÔNG TY CỔ PHẦN MẶT DỰNG CAG (ID: 22079986), có giấy CNĐKDN số 0101442420, địa chỉ tại KCN Thạch Thất, Hà Nội. Người đại diện theo pháp luật là Tổng Giám đốc Đào Công Duy. Công ty có 3 nhà máy sản xuất và thi công vách kính mặt dựng, với tổng nguồn vốn cần sử dụng là 800 tỷ (trong đó vốn vay là 400 tỷ). Hiệu quả kinh doanh dự kiến đạt doanh thu 950 tỷ và lợi nhuận 55 tỷ. Tài sản bảo đảm bao gồm các nhà máy và hoạt động sản xuất, với đầu vào chủ yếu là nhôm thanh và kính nhập khẩu hoặc sản xuất trong nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Thông tin khách hàng là CÔNG TY CỔ PHẦN MẶT DỰNG CAG (ID: 22079986), có giấy CNĐKDN số 0101442420, địa chỉ tại KCN Thạch Thất, Hà Nội. Người đại diện theo pháp luật là Tổng Giám đốc Đào Công Duy. Công ty có 3 nhà máy sản xuất và thi công vách kính mặt dựng, với tổng nguồn vốn cần sử dụng là 800 tỷ (trong đó vốn vay là 400 tỷ). Hiệu quả kinh doanh dự kiến đạt doanh thu 950 tỷ và lợi nhuận 55 tỷ. Tài sản bảo đảm bao gồm các nhà máy và hoạt động sản xuất, với đầu vào chủ yếu là nhôm thanh và kính nhập khẩu hoặc sản xuất trong nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 18/40 ---
# ❓ Câu hỏi: Nhận xét về pháp lý/GPKD có điều kiện là gì?
#
# --- Query 18/40 ---
# ❓ Câu hỏi: Nhận xét về pháp lý/GPKD có điều kiện là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 19/40 ---
# ❓ Câu hỏi: Nhận xét về chủ doanh nghiệp/ban lãnh đạo là gì?
#
# --- Query 19/40 ---
# ❓ Câu hỏi: Nhận xét về chủ doanh nghiệp/ban lãnh đạo là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 20/40 ---
# ❓ Câu hỏi: Nhận xét về KYC là gì?
#
# --- Query 20/40 ---
# ❓ Câu hỏi: Nhận xét về KYC là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 21/40 ---
# ❓ Câu hỏi: Lĩnh vực kinh doanh của công ty là gì?
#
# --- Query 21/40 ---
# ❓ Câu hỏi: Lĩnh vực kinh doanh của công ty là gì?
# ✅ Câu trả lời của hệ thống: Lĩnh vực kinh doanh của các công ty trong context bao gồm:
# - **Sunspace**: Sản xuất và thi công hệ thống vách kính, mặt dựng, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, cửa cuốn.
# - **CAG**: Sản xuất mặt dựng kính, tấm ốp Alu, cửa kính (tự động, mở quay, lùa), cửa sổ, lam chắn nắng, cầu thang kính.
# - **Eurowindow**: Sản xuất cửa uPVC, cửa gỗ, nội thất, cửa cuốn, cửa chống cháy, cửa nhôm, hệ vách nhôm kính, kính.
# - **BM Windows**: Sản xuất mặt dựng nhôm kính và hệ thống cửa.
#
# Nếu cần cụ thể từng công ty, vui lòng chỉ rõ.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Lĩnh vực kinh doanh của các công ty trong context bao gồm:
# - **Sunspace**: Sản xuất và thi công hệ thống vách kính, mặt dựng, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, cửa cuốn.
# - **CAG**: Sản xuất mặt dựng kính, tấm ốp Alu, cửa kính (tự động, mở quay, lùa), cửa sổ, lam chắn nắng, cầu thang kính.
# - **Eurowindow**: Sản xuất cửa uPVC, cửa gỗ, nội thất, cửa cuốn, cửa chống cháy, cửa nhôm, hệ vách nhôm kính, kính.
# - **BM Windows**: Sản xuất mặt dựng nhôm kính và hệ thống cửa.
#
# Nếu cần cụ thể từng công ty, vui lòng chỉ rõ.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 22/40 ---
# ❓ Câu hỏi: Sản phẩm/dịch vụ của công ty là gì?
#
# --- Query 22/40 ---
# ❓ Câu hỏi: Sản phẩm/dịch vụ của công ty là gì?
# ✅ Câu trả lời của hệ thống: Sản phẩm/dịch vụ của các công ty được liệt kê trong context bao gồm:
#
# - **Sunspace**: Hệ thống vách kính, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, cửa cuốn.
# - **CAG**: Hệ thống mặt dựng kính, tấm ốp Alu, cửa kính (tự động, mở quay, đi lùa), lam chắn nắng, cầu thang kính.
# - **Eurowindow**: Cửa uPVC, cửa gỗ, nội thất, cửa cuốn, cửa chống cháy, cửa nhôm, hệ vách nhôm kính, kính.
# - **BM Windows**: Mặt dựng nhôm kính, hệ thống cửa.
#
# Nếu cần cụ thể hơn, vui lòng chỉ rõ công ty nào.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Sản phẩm/dịch vụ của các công ty được liệt kê trong context bao gồm:
#
# - **Sunspace**: Hệ thống vách kính, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, cửa cuốn.
# - **CAG**: Hệ thống mặt dựng kính, tấm ốp Alu, cửa kính (tự động, mở quay, đi lùa), lam chắn nắng, cầu thang kính.
# - **Eurowindow**: Cửa uPVC, cửa gỗ, nội thất, cửa cuốn, cửa chống cháy, cửa nhôm, hệ vách nhôm kính, kính.
# - **BM Windows**: Mặt dựng nhôm kính, hệ thống cửa.
#
# Nếu cần cụ thể hơn, vui lòng chỉ rõ công ty nào.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 23/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N-1 (%) là bao nhiêu?
#
# --- Query 23/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N-1 (%) là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 24/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N (%) là bao nhiêu?
#
# --- Query 24/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm N (%) là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 25/40 ---
# ❓ Câu hỏi: Nhóm mặt hàng của công ty là gì?
#
# --- Query 25/40 ---
# ❓ Câu hỏi: Nhóm mặt hàng của công ty là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 26/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm 2023 là bao nhiêu?
#
# --- Query 26/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu năm 2023 là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 27/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu 10T/2024 là bao nhiêu?
#
# --- Query 27/40 ---
# ❓ Câu hỏi: Tỷ trọng doanh thu 10T/2024 là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 28/40 ---
# ❓ Câu hỏi: Mô tả chung về sản phẩm của công ty là gì?
#
# --- Query 28/40 ---
# ❓ Câu hỏi: Mô tả chung về sản phẩm của công ty là gì?
# ✅ Câu trả lời của hệ thống: Sản phẩm của công ty bao gồm hệ thống vách kính mặt dựng, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, và cửa cuốn. Công ty chủ yếu thi công các dự án của Vingroup và các tổng thầu lớn như Hòa Bình, BIM group.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Sản phẩm của công ty bao gồm hệ thống vách kính mặt dựng, cửa nhôm, cabin tắm, lan can kính, cửa nhựa uPVC, cửa kính tự động, và cửa cuốn. Công ty chủ yếu thi công các dự án của Vingroup và các tổng thầu lớn như Hòa Bình, BIM group.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 29/40 ---
# ❓ Câu hỏi: Mô tả lợi thế cạnh tranh của công ty là gì?
#
# --- Query 29/40 ---
# ❓ Câu hỏi: Mô tả lợi thế cạnh tranh của công ty là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 30/40 ---
# ❓ Câu hỏi: Mô tả năng lực đấu thầu của công ty là gì?
#
# --- Query 30/40 ---
# ❓ Câu hỏi: Mô tả năng lực đấu thầu của công ty là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 31/40 ---
# ❓ Câu hỏi: Quy trình vận hành (tóm tắt) của công ty là gì?
#
# --- Query 31/40 ---
# ❓ Câu hỏi: Quy trình vận hành (tóm tắt) của công ty là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 32/40 ---
# ❓ Câu hỏi: Đầu vào - mặt hàng là gì?
#
# --- Query 32/40 ---
# ❓ Câu hỏi: Đầu vào - mặt hàng là gì?
# ✅ Câu trả lời của hệ thống: Đầu vào - mặt hàng bao gồm:
# - **Nhôm thanh**:
#   + Kích thước nhỏ: sản xuất trong nước
#   + Kích thước lớn: nhập khẩu từ Trung Quốc
# - **Phôi kính**:
#   + Kính không màu: sản xuất trong nước
#   + Kính màu/nhập khẩu: mua qua đơn vị trung gian do hạn chế chi phí và tiến độ khi nhập trực tiếp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Đầu vào - mặt hàng bao gồm:
# - **Nhôm thanh**:
#   + Kích thước nhỏ: sản xuất trong nước
#   + Kích thước lớn: nhập khẩu từ Trung Quốc
# - **Phôi kính**:
#   + Kính không màu: sản xuất trong nước
#   + Kính màu/nhập khẩu: mua qua đơn vị trung gian do hạn chế chi phí và tiến độ khi nhập trực tiếp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 33/40 ---
# ❓ Câu hỏi: Đầu vào - chi tiết là gì?
#
# --- Query 33/40 ---
# ❓ Câu hỏi: Đầu vào - chi tiết là gì?
# ✅ Câu trả lời của hệ thống: Đầu vào bao gồm:
# - **Nhôm thanh:**
#   - Các mã kích thước nhỏ: sản xuất trong nước.
#   - Các mã kích thước lớn: nhập khẩu từ Trung Quốc.
# - **Phôi kính:**
#   - Kính không màu: sản xuất trong nước.
#   - Kính màu: nhập khẩu thông qua các đơn vị chuyên nhập phôi kính do không đáp ứng được chi phí và tiến độ nếu nhập trực tiếp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Đầu vào bao gồm:
# - **Nhôm thanh:**
#   - Các mã kích thước nhỏ: sản xuất trong nước.
#   - Các mã kích thước lớn: nhập khẩu từ Trung Quốc.
# - **Phôi kính:**
#   - Kính không màu: sản xuất trong nước.
#   - Kính màu: nhập khẩu thông qua các đơn vị chuyên nhập phôi kính do không đáp ứng được chi phí và tiến độ nếu nhập trực tiếp.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 34/40 ---
# ❓ Câu hỏi: Đầu vào - phương thức thanh toán là gì?
#
# --- Query 34/40 ---
# ❓ Câu hỏi: Đầu vào - phương thức thanh toán là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 35/40 ---
# ❓ Câu hỏi: Đầu ra - kênh phân phối là gì?
#
# --- Query 35/40 ---
# ❓ Câu hỏi: Đầu ra - kênh phân phối là gì?
# ✅ Câu trả lời của hệ thống: Đầu ra - kênh phân phối của công ty bao gồm:
# - Phần lớn ký trực tiếp với chủ đầu tư.
# - Một số trường hợp ký với tổng thầu & CAG là nhà thầu do CĐT chỉ định.
# - Công ty ít ký hợp đồng với tư cách nhà thầu phụ.
# - Dân dụng: các tòa nhà văn phòng, trung tâm thương mại.
# - Ngân sách nhà nước: các tòa nhà ủy ban, trung tâm hành chính, hội nghị, văn hóa của các tỉnh thành phố.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Đầu ra - kênh phân phối của công ty bao gồm:
# - Phần lớn ký trực tiếp với chủ đầu tư.
# - Một số trường hợp ký với tổng thầu & CAG là nhà thầu do CĐT chỉ định.
# - Công ty ít ký hợp đồng với tư cách nhà thầu phụ.
# - Dân dụng: các tòa nhà văn phòng, trung tâm thương mại.
# - Ngân sách nhà nước: các tòa nhà ủy ban, trung tâm hành chính, hội nghị, văn hóa của các tỉnh thành phố.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 36/40 ---
# ❓ Câu hỏi: Đầu ra - tỷ trọng là bao nhiêu?
#
# --- Query 36/40 ---
# ❓ Câu hỏi: Đầu ra - tỷ trọng là bao nhiêu?
# ✅ Câu trả lời của hệ thống: Tỷ trọng doanh thu với nhóm đầu ra chính được phân loại như sau:
# - **Khuyến khích (KK):** X ≥ 70%
# - **Bình thường (BT):** 50% ≤ X < 70%
# - **Thận trọng (TT):** 30% ≤ X < 50%
# - **Hạn chế (HC):** X < 30%
#
# (Áp dụng cho các nhóm: dân dụng/công nghiệp, SX VLXD nhóm 23950 & 23960, SX gỗ theo PL tiêu chí người mua).
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tỷ trọng doanh thu với nhóm đầu ra chính được phân loại như sau:
# - **Khuyến khích (KK):** X ≥ 70%
# - **Bình thường (BT):** 50% ≤ X < 70%
# - **Thận trọng (TT):** 30% ≤ X < 50%
# - **Hạn chế (HC):** X < 30%
#
# (Áp dụng cho các nhóm: dân dụng/công nghiệp, SX VLXD nhóm 23950 & 23960, SX gỗ theo PL tiêu chí người mua).
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 37/40 ---
# ❓ Câu hỏi: Đầu ra - phương thức thanh toán là gì?
#
# --- Query 37/40 ---
# ❓ Câu hỏi: Đầu ra - phương thức thanh toán là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 38/40 ---
# ❓ Câu hỏi: Nhận xét tổng quan về hoạt động kinh doanh là gì?
#
# --- Query 38/40 ---
# ❓ Câu hỏi: Nhận xét tổng quan về hoạt động kinh doanh là gì?
# ✅ Câu trả lời của hệ thống: Khách hàng có 3 nhà máy sản xuất, lắp ráp và thi công vách kính mặt dựng tại các tòa nhà cao tầng. Đầu vào chủ yếu là nhôm thanh và kính nhập khẩu hoặc sản xuất trong nước, đầu ra chủ yếu ký trực tiếp với chủ đầu tư hoặc tổng thầu. Hoạt động kinh doanh tập trung vào các dự án dân dụng và ngân sách nhà nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Khách hàng có 3 nhà máy sản xuất, lắp ráp và thi công vách kính mặt dựng tại các tòa nhà cao tầng. Đầu vào chủ yếu là nhôm thanh và kính nhập khẩu hoặc sản xuất trong nước, đầu ra chủ yếu ký trực tiếp với chủ đầu tư hoặc tổng thầu. Hoạt động kinh doanh tập trung vào các dự án dân dụng và ngân sách nhà nước.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 39/40 ---
# ❓ Câu hỏi: Phân tích cung cầu ngành là gì?
#
# --- Query 39/40 ---
# ❓ Câu hỏi: Phân tích cung cầu ngành là gì?
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
# ✅ Câu trả lời của hệ thống: Tôi không tìm thấy thông tin trong tài liệu.
# ----------------------------------------
# ⏳ Đợi 10 giây...
#
# --- Query 40/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin ngành là gì?
#
# --- Query 40/40 ---
# ❓ Câu hỏi: Nhận xét về thông tin ngành là gì?
# ✅ Câu trả lời của hệ thống: Thông tin ngành được phân loại theo các tiêu chí cụ thể như doanh thu, nhà xưởng, năng lực quản lý, và tỷ lệ tài sản đảm bảo. Các mức độ từ Khuyến khích (KK) đến Hạn chế (HC) giúp đánh giá rủi ro và tiềm năng của doanh nghiệp trong ngành sản xuất gỗ và xây dựng.
# ----------------------------------------
#
#
# ✅ Đã thu thập xong toàn bộ dữ liệu (answer, context).
# ✅ Câu trả lời của hệ thống: Thông tin ngành được phân loại theo các tiêu chí cụ thể như doanh thu, nhà xưởng, năng lực quản lý, và tỷ lệ tài sản đảm bảo. Các mức độ từ Khuyến khích (KK) đến Hạn chế (HC) giúp đánh giá rủi ro và tiềm năng của doanh nghiệp trong ngành sản xuất gỗ và xây dựng.
# ----------------------------------------
#
#
# ✅ Đã thu thập xong toàn bộ dữ liệu (answer, context).
#                                             question  \
# 0                   Tên đầy đủ của khách hàng là gì?
# 1  Số giấy phép đăng ký kinh doanh của khách hàng...
# 2                               ID khách hàng là gì?
# 3                    Phân khúc của khách hàng là gì?
# 4                             Loại khách hàng là gì?
#
#                                               answer  \
# 0  Tên đầy đủ của khách hàng là: CÔNG TY CỔ PHẦN ...
# 1  Số giấy phép đăng ký kinh doanh của khách hàng...
# 2                     ID khách hàng là **22079986**.
# 3  Phân khúc khách hàng của các doanh nghiệp tron...
# 4  Loại khách hàng của CÔNG TY CỔ PHẦN MẶT DỰNG C...
#
#                                             contexts
# 0  [*(Áp dụng cho khoản tín dụng món/hạn mức tín ...
# 1  [*(Áp dụng cho khoản tín dụng món/hạn mức tín ...
# 2  [*(Áp dụng cho khoản tín dụng món/hạn mức tín ...
# 3  [---\n\n**Hà Nội, Ngày 09 tháng 04 năm 2024**\...
# 4  [**Nhà máy miền Nam:**\n- Địa điểm: Đồng Nai\n...
# ✅ Đã lưu kết quả vào file: output_parsing/generated_data_for_eval(full_raw_input_claude_parsing_deepseek).json

# %% [markdown]
# # RAGAS Evaluation

# %%
from ragas_evaluation import RagasEvaluator
import pandas as pd
from pathlib import Path
import json

# 1. Khởi tạo Evaluator
evaluator = RagasEvaluator(list_of_api_keys=LIST_GOOGLE_API_KEYS)

# Load generated data từ file JSON: (generated data is RAG output: question, LLM answer, context)
generated_data_file = Path('/root/chatbot1/chatbot_document/backend/new/output_parsing/generated_data_for_eval(full_raw_input_claude_parsing).json')
if not generated_data_file.exists():
    print(f"❌ Lỗi: Không tìm thấy file {generated_data_file}. Vui lòng chạy bước thu thập dữ liệu trước.")
else:
    with open(generated_data_file, 'r', encoding='utf-8') as f:
        generated_data_for_eval = json.load(f)
        
# 2.  Load base data (chứa question và ground_truth)
base_data = evaluator.load_base_dataset(Path('backend/schemas/ragasdf_base.json'))

# 3. Chuẩn bị dataset hoàn chỉnh bằng cách kết hợp base_data và generated_data
'''
Evaluation dataset includes:
- question
- ground_truth (optional but need for some metrics: answer_correctness)
- contexts (list of context strings)
- answer (LLM generated answer)
'''
eval_dataset = evaluator.prepare_evaluation_dataset(
    base_data=base_data,
    generated_data=generated_data_for_eval 
)

# 4. Xuất file dataset RAGAS hoàn chỉnh ra Excel để kiểm tra
if eval_dataset:
    ragas_df = eval_dataset.to_pandas()
    ragas_df['context_count'] = ragas_df['contexts'].apply(len)
    output_df_path = "ragas_dataset_for_evaluation(full_raw_input_claude_parsing_deepseek).xlsx"
    ragas_df.to_excel(output_df_path, index=False)
    print(f"💾 Đã xuất file dataset RAGAS hoàn chỉnh ra: {output_df_path}")
    
# 5. Chạy đánh giá
# if eval_dataset:
#     results_df = evaluator.run_evaluation(eval_dataset)

#     if results_df is not None:
#         # 6. Hiển thị và lưu báo cáo
#         print("\n\n--- 📊 KẾT QUẢ ĐÁNH GIÁ CHI TIẾT ---")
#         display(results_df)
#         report_dir = "evaluation_reports"
#         report_filename = "ragas_report(full_raw_input_claude_parsing_deepseek).xlsx"
#         saved_path = evaluator.save_report(results_df, output_dir=report_dir, filename=report_filename)
#         if saved_path:
#             print(f"✅ Báo cáo đã được lưu tại: {saved_path}")
#         else:
#             print("❌ Không thể lưu báo cáo.")
#     else:
#         print("❌ Đánh giá không trả về kết quả.")
# else:
#     print("❌ Không thể tạo dataset để đánh giá.")


if eval_dataset:
    results_df = evaluator.run_evaluation(eval_dataset)

    if results_df is not None:
        # 6. Hiển thị và lưu báo cáo
        print("\n\n--- 📊 KẾT QUẢ ĐÁNH GIÁ CHI TIẾT ---")
        display(results_df)
        report_dir = "evaluation_reports"
        report_filename = "ragas_report(full_raw_input_claude_parsing_deepseek).xlsx"
        saved_path = evaluator.save_report(results_df, output_dir=report_dir, filename=report_filename)
        if saved_path:
            print(f"✅ Báo cáo đã được lưu tại: {saved_path}")
        else:
            print("❌ Không thể lưu báo cáo.")
            

        evaluator.display_evaluation_cost()
            
    else:
        print("❌ Đánh giá không trả về kết quả.")
else:
    print("❌ Không thể tạo dataset để đánh giá.")
# Out:
# 🚀 Khởi tạo RagasEvaluator (có Retry & Key Switching)...
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# LLM và Embeddings đã sẵn sàng.
# 📋 Đã định nghĩa 5 metrics: ['faithfulness', 'context_precision', 'context_recall', 'answer_correctness', 'semantic_similarity']
# Đã tạo thư mục báo cáo: evaluation_reports
# Đang tải base dataset từ: backend/schemas/ragasdf_base.json
# Lỗi khi tải base dataset: [Errno 2] No such file or directory: 'backend/schemas/ragasdf_base.json'
# Đang chuẩn bị dataset để đánh giá...
# Base data or generated data is empty, cannot create evaluation dataset.
# ❌ Không thể tạo dataset để đánh giá.
